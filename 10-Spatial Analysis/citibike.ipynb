# %% [markdown]
# # Example: CitiBike data
#
# Adapted from Kelsey Jordahl
# https://gist.github.com/kjordahl/5957573

# %%
import requests  
import json
from pyproj import Proj
from shapely.geometry import Point
import geopandas as gp
import pandas as pd

# %% [markdown]
# NYC borough boundaries downloaded from [Bytes of the Big Apple](http://www.nyc.gov/html/dcp/download/bytes/nybb_13a.zip)

# %%
boros = gp.GeoDataFrame.from_file('nybb_15b/nybb.shp')
boros.crs
# Out:
# {'proj': 'lcc',
#  'lat_1': 40.66666666666666,
#  'lat_2': 41.03333333333333,
#  'lat_0': 40.16666666666666,
#  'lon_0': -74,
#  'x_0': 300000,
#  'y_0': 0,
#  'datum': 'NAD83',
#  'units': 'us-ft',
#  'no_defs': True}

# %% [markdown]
# Load real time bike station data from [CitiBike](http://citibikenyc.com) json API:

# %%
# get the bike data and convert it to a ditcionary
endpoint_url = 'http://citibikenyc.com/stations/json'
response = requests.get(endpoint_url)
data = json.loads(response.text)

# %%
# convert the relevant part to a geodataframe
df = gp.GeoDataFrame(data['stationBeanList'])
df
# Out:
#     altitude  availableBikes  availableDocks city    id landMark  \
# 0                          6              26        304
# 1                         15              44        359
# 2                         12              33        377
# 3                         27              10        402
# 4                          8              10       3255
# 5                         18              21       3443
# 6                         32              23         72
# 7                         32               0         79
# 8                         23               3         82
# 9                         33              29         83
# 10                        10               9        119
# 11                         4              15        120
# 12                        20               6        127
# 13                        23               3        128
# 14                        20               3        143
# 15                        14               4        144
# 16                        22              16        146
# 17                         4              49        150
# 18                        32               0        151
# 19                         3              19        157
# 20                        33               1        161
# 21                        23              24        164
# 22                        19              24        167
# 23                        47               0        168
# 24                        39              11        173
# 25                        22               7        174
# 26                        15              30        195
# 27                        27               0        212
# 28                         8              13        216
# 29                        21              16        217
# ..       ...             ...             ...  ...   ...      ...
# 784                        2              45       3689
# 785                       28               7       3690
# 786                        0              18       3691
# 787                       14               0       3692
# 788                       19               5       3693
# 789                        6              12       3694
# 790                       17              26       3697
# 791                        1              29       3699
# 792                       33               3       3701
# 793                       16               3       3704
# 794                       52               1       3707
# 795                       27               0       3708
# 796                       22              27       3709
# 797                        3              43       3711
# 798                       20              21       3712
# 799                       17              44       3714
# 800                       29               1       3715
# 801                        1              22       3716
# 802                        4              42       3718
# 803                       20               2       3720
# 804                        4              14       3721
# 805                       13              17       3723
# 806                        6              32       3724
# 807                        4              37       3725
# 808                        2              18       3726
# 809                        6              32       3727
# 810                        7              17       3728
# 811                       11              35       3733
# 812                       32               3       3737
# 813                        3              24       3745
#
#       lastCommunicationTime   latitude location  longitude postalCode  \
# 0    2019-02-28 12:38:29 PM  40.704633          -74.013617
# 1    2019-02-28 12:34:54 PM  40.755103          -73.974987
# 2    2019-02-28 12:37:10 PM  40.722438          -74.005664
# 3    2019-02-28 12:37:07 PM  40.740343          -73.989551
# 4    2019-02-28 12:37:52 PM  40.750585          -73.994685
# 5    2019-02-28 12:37:04 PM  40.761330          -73.979820
# 6    2019-02-28 12:36:59 PM  40.767272          -73.993929
# 810  2019-02-28 12:35:34 PM  40.695357          -73.993440
# 811  2019-02-28 12:38:28 PM  40.730563          -73.973984
# 812  2019-02-28 12:36:40 PM  40.720747          -73.986274
# 813  2019-02-28 12:37:18 PM  40.756513          -73.929575
#
#                            stAddress1 stAddress2  \
# 0               Broadway & Battery Pl
# 1                  E 47 St & Park Ave
# 2                    6 Ave & Canal St
# 3                  Broadway & E 22 St
# 4                     8 Ave & W 31 St
# 5                     W 52 St & 6 Ave
# 6                    W 52 St & 11 Ave
# 7            Franklin St & W Broadway
# 8              St James Pl & Pearl St
# 9       Atlantic Ave & Fort Greene Pl
# 10           Park Ave & St Edwards St
# 11        Lexington Ave & Classon Ave
# 12              Barrow St & Hudson St
# 13           MacDougal St & Prince St
# 14          Clinton St & Joralemon St
# 15                Nassau St & Navy St
# 16               Hudson St & Reade St
# 17                  E 2 St & Avenue C
# 18           Cleveland Pl & Spring St
# 19            Henry St & Atlantic Ave
# 20              LaGuardia Pl & W 3 St
# 21                    E 47 St & 2 Ave
# 22                    E 39 St & 3 Ave
# 23                    W 18 St & 6 Ave
# 24                 Broadway & W 49 St
# 25                    E 25 St & 1 Ave
# 26              Liberty St & Broadway
# 27            W 16 St & The High Line
# 28    Columbia Heights & Cranberry St
# 29                      Old Fulton St
# ..                                ...        ...
# 784          W 104 St & Amsterdam Ave
# 785               Park Pl & Church St
# 786                    28 Ave & 44 St
# 787                  5 St & Market St
# 788                N 11 St & Kent Ave
# 789                    Jackson Square
# 790  W 64 St & Thelonious Monk Circle
# 791                   W 50 St & 9 Ave
# 792              Cliff St & Fulton St
# 793             47 Ave & Skillman Ave
# 794           Lexington Ave & E 26 St
# 795                   W 13 St & 5 Ave
# 796                   W 15 St & 6 Ave
# 797                E 13 St & Avenue A
# 798                W 35 St & Dyer Ave
# 799           Division Av & Hooper St
# 800               Driggs Ave & N 9 St
# 801              40 Ave & Crescent St
# 802                E 11 St & Avenue B
# 803              Wyckoff St & Bond St
# 804               31 St & Newtown Ave
# 805       Cadman Plaza E & Johnson St
# 806        7 Ave & Central Park South
# 807                   2 Ave & E 72 St
# 808              Center Blvd & 51 Ave
# 809             Frost St & Meeker Ave
# 810         Pierrepont St & Monroe Pl
# 811                Avenue C & E 18 St
# 812           Stanton St & Norfolk St
# 813                    36 Ave & 31 St
#
#                           stationName  statusKey statusValue  testStation  \
# 0               Broadway & Battery Pl          1  In Service        False
# 1                  E 47 St & Park Ave          1  In Service        False
# 2                    6 Ave & Canal St          1  In Service        False
# 3                  Broadway & E 22 St          1  In Service        False
# 4                     8 Ave & W 31 St          1  In Service        False
# 5                     W 52 St & 6 Ave          1  In Service        False
# 6                    W 52 St & 11 Ave          1  In Service        False
# 7            Franklin St & W Broadway          1  In Service        False
# 8              St James Pl & Pearl St          1  In Service        False
# 9       Atlantic Ave & Fort Greene Pl          1  In Service        False
# 10           Park Ave & St Edwards St          1  In Service        False
# 11        Lexington Ave & Classon Ave          1  In Service        False
# 12              Barrow St & Hudson St          1  In Service        False
# 13           MacDougal St & Prince St          1  In Service        False
# 14          Clinton St & Joralemon St          1  In Service        False
# 15                Nassau St & Navy St          1  In Service        False
# 16               Hudson St & Reade St          1  In Service        False
# 17                  E 2 St & Avenue C          1  In Service        False
# 18           Cleveland Pl & Spring St          1  In Service        False
# 19            Henry St & Atlantic Ave          1  In Service        False
# 20              LaGuardia Pl & W 3 St          1  In Service        False
# 21                    E 47 St & 2 Ave          1  In Service        False
# 22                    E 39 St & 3 Ave          1  In Service        False
# 23                    W 18 St & 6 Ave          1  In Service        False
# 24                 Broadway & W 49 St          1  In Service        False
# 25                    E 25 St & 1 Ave          1  In Service        False
# 26              Liberty St & Broadway          1  In Service        False
# 27            W 16 St & The High Line          1  In Service        False
# 28    Columbia Heights & Cranberry St          1  In Service        False
# 29                      Old Fulton St          1  In Service        False
# ..                                ...        ...         ...          ...
# 784          W 104 St & Amsterdam Ave          1  In Service        False
# 785               Park Pl & Church St          1  In Service        False
# 786                    28 Ave & 44 St          1  In Service        False
# 787                  5 St & Market St          1  In Service        False
# 788                N 11 St & Kent Ave          1  In Service        False
# 789                    Jackson Square          1  In Service        False
# 790  W 64 St & Thelonious Monk Circle          1  In Service        False
# 791                   W 50 St & 9 Ave          1  In Service        False
# 792              Cliff St & Fulton St          1  In Service        False
# 793             47 Ave & Skillman Ave          1  In Service        False
# 794           Lexington Ave & E 26 St          1  In Service        False
# 795                   W 13 St & 5 Ave          1  In Service        False
# 796                   W 15 St & 6 Ave          1  In Service        False
# 797                E 13 St & Avenue A          1  In Service        False
# 798                W 35 St & Dyer Ave          1  In Service        False
# 799           Division Av & Hooper St          1  In Service        False
# 800               Driggs Ave & N 9 St          1  In Service        False
# 801              40 Ave & Crescent St          1  In Service        False
# 802                E 11 St & Avenue B          1  In Service        False
# 803              Wyckoff St & Bond St          1  In Service        False
# 804               31 St & Newtown Ave          1  In Service        False
# 805       Cadman Plaza E & Johnson St          1  In Service        False
# 806        7 Ave & Central Park South          1  In Service        False
# 807                   2 Ave & E 72 St          1  In Service        False
# 808              Center Blvd & 51 Ave          1  In Service        False
# 809             Frost St & Meeker Ave          1  In Service        False
# 810         Pierrepont St & Monroe Pl          1  In Service        False
# 811                Avenue C & E 18 St          1  In Service        False
# 812           Stanton St & Norfolk St          1  In Service        False
# 813                    36 Ave & 31 St          1  In Service        False
#
#      totalDocks
# 0            33
# 1            64
# 2            45
# 3            39
# 4            19
# 5            41
# 6            55
# 7            33
# 8            27
# 9            62
# 10           19
# 11           19
# 12           31
# 13           30
# 14           24
# 15           19
# 16           39
# 17           54
# 18           33
# 19           23
# 20           35
# 21           47
# 22           45
# 23           47
# 24           51
# 25           30
# 26           45
# 27           28
# 28           23
# 29           39
# ..          ...
# 784          47
# 785          36
# 786          19
# 787          15
# 788          27
# 789          18
# 790          43
# 791          30
# 792          37
# 793          19
# 794          55
# 795          29
# 796          51
# 797          47
# 798          41
# 799          61
# 800          31
# 801          23
# 802          46
# 803          23
# 804          35
# 805          30
# 806          39
# 807          41
# 808          20
# 809          38
# 810          24
# 811          46
# 812          35
# 813          27
#
# [814 rows x 18 columns]

# %%
# there is one row for each bike station.  How many stations are there? 
len(df)
# Out:
# 814

# %%
# in the file above, there are lon-lats, but no geometry field
# we need to set that up

s = gp.GeoSeries([Point(x, y) for x, y in zip(df['longitude'], df['latitude'])])
df['geometry'] = s
df.crs = {'init': 'epsg:4326', 'no_defs': True}
df.geometry.total_bounds
df.crs
# Out:
# {'init': 'epsg:4326', 'no_defs': True}

# %%
# make sure they are on the same CRS.  
# checking the bounds is a nice way of seeing this
df.to_crs(boros.crs, inplace=True)
df.geometry.total_bounds
# Out:
# array([ 961064.73659426,  178056.37414829, 1009803.53178432,
#         235986.42166716])

# %%
# the geometry objects can do lots of cool stuff.  For example: 

manhattan = boros.geometry[3]
in_mn = df.geometry.within(manhattan)
print(sum(in_mn), 'stations in Manhattan')
# Out:
# 415 stations in Manhattan

# %% [markdown]
# # Your turn
#
# You can read about the range of operations available in geopandas here:
#
# http://geopandas.org/index.html
#
# Your assignment is to:
#
# 1. Calculate how many stations are in each borough
# 2. Calculate how many bikes are currently available in each borough
# 3. Read about and try at least two new spatial or geometric operations (beyond what I've covered here).

# %% [markdown]
# ### 1. Calculate how many stations are in each borough

# %%
# join the citibike data with boros using the within operation
citibikes_boros = gp.sjoin(df, boros, how="left", op='within')

# %%
#Note, 50 stations are not within any boro
sum(citibikes_boros.BoroName.isna())
# Out:
# 50

# %%
c = citibikes_boros.BoroName.value_counts().to_frame(name='stations')
# Add boros with 0 stations
pd.merge(boros[['BoroName']],c, how='left', right_index=True, left_on= 'BoroName').fillna(0)
# Out:
#         BoroName  stations
# 0  Staten Island       0.0
# 1       Brooklyn     267.0
# 2         Queens      82.0
# 3      Manhattan     415.0
# 4          Bronx       0.0

# %% [markdown]
# ### 2. Calculate how many bikes are currently available in each borough

# %%
# get sum of bikes
bikes = citibikes_boros.groupby('BoroName')['availableBikes'].sum()
bikes
# Out:
# BoroName
# Brooklyn     3375
# Manhattan    7003
# Queens        401
# Name: availableBikes, dtype: int64

# %%
# Add boros with 0 bikes
bikes = bikes.to_frame(name='bikes')
pd.merge(boros[['BoroName']],bikes, right_index=True, left_on= 'BoroName', how='left').fillna(0)
# Out:
#         BoroName   bikes
# 0  Staten Island     0.0
# 1       Brooklyn  3375.0
# 2         Queens   401.0
# 3      Manhattan  7003.0
# 4          Bronx     0.0

# %% [markdown]
# ### 3. Read about and try at least two new spatial or geometric operations (beyond what I've covered here).
#
# 1. sjoin() - Used in exercise one
# 2. dissolve(): It dissolves all the geometries within a given group together into a single geometric feature
# 3. touches(): It checks if two objects has at least one point in common and the interior of one does not intersect with any part of the other.

# %%
try_touches = boros.BoroName.to_frame()
for index, row in boros.iterrows():
    try_touches[row.BoroName] = boros.geometry.touches(row.geometry)
    
try_touches
# Out:
#         BoroName  Staten Island  Brooklyn  Queens  Manhattan  Bronx
# 0  Staten Island          False     False   False      False  False
# 1       Brooklyn          False     False    True       True  False
# 2         Queens          False      True   False       True   True
# 3      Manhattan          False      True    True      False   True
# 4          Bronx          False     False    True       True  False

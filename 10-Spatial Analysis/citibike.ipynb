# %% [markdown]
# # Example: CitiBike data
#
# Adapted from Kelsey Jordahl
# https://gist.github.com/kjordahl/5957573

# %%
import requests  
import json
from pyproj import Proj
from shapely.geometry import Point
import geopandas as gp
import pandas as pd

# %% [markdown]
# NYC borough boundaries downloaded from [Bytes of the Big Apple](http://www.nyc.gov/html/dcp/download/bytes/nybb_13a.zip)

# %%
boros = gp.GeoDataFrame.from_file('nybb_15b/nybb.shp')
boros.crs
# Out:
# {'proj': 'lcc',
#  'lat_1': 40.66666666666666,
#  'lat_2': 41.03333333333333,
#  'lat_0': 40.16666666666666,
#  'lon_0': -74,
#  'x_0': 300000,
#  'y_0': 0,
#  'datum': 'NAD83',
#  'units': 'us-ft',
#  'no_defs': True}

# %% [markdown]
# Load real time bike station data from [CitiBike](http://citibikenyc.com) json API:

# %%
# get the bike data and convert it to a ditcionary
endpoint_url = 'http://citibikenyc.com/stations/json'
response = requests.get(endpoint_url)
data = json.loads(response.text)

# %%
# convert the relevant part to a geodataframe
df = gp.GeoDataFrame(data['stationBeanList'])
df
# Out:
#     altitude  availableBikes  availableDocks city    id landMark  \
# 0                         30              22         72
# 1                         24               9         79
# 2                         25               1         82
# 3                         27              35         83
# 4                         10               9        119
# 5                         15               4        120
# 6                         30               1        127
# 7                         25               2        128
# 8                          6              17        143
# 9                         12               5        144
# 10                        26              10        146
# 11                        31              21        150
# 12                        19              11        151
# 13                        20               1        157
# 14                        26               9        161
# 15                         0              47        164
# 16                         0              43        167
# 17                         2              44        168
# 18                         0              51        173
# 19                         7              22        174
# 20                         2              43        195
# 21                        12              13        212
# 22                        14               6        216
# 23                        15              23        217
# 24                        28               2        223
# 25                        17              13        224
# 26                         0              55        228
# 27                        17               4        229
# 28                        44               2        236
# 29                        32               5        237
# ..       ...             ...             ...  ...   ...      ...
# 786                        0               3       3689
# 787                       26              10       3690
# 788                        2              17       3691
# 789                        4              11       3692
# 790                       21               5       3693
# 791                        6              12       3694
# 792                       29              12       3697
# 793                        7              22       3699
# 794                       25              11       3701
# 795                       19               0       3704
# 796                       15              39       3707
# 797                       18               9       3708
# 798                       38              11       3709
# 799                       40               5       3711
# 800                        7              34       3712
# 801                        3              58       3714
# 802                       13              17       3715
# 803                        1              22       3716
# 804                       45               0       3718
# 805                       23               0       3720
# 806                        0              18       3721
# 807                       11              19       3723
# 808                        3              36       3724
# 809                        3              36       3725
# 810                        2              18       3726
# 811                        7              30       3727
# 812                        5              19       3728
# 813                       12              34       3733
# 814                       28               7       3737
# 815                        4              21       3745
#
#       lastCommunicationTime   latitude location  longitude postalCode  \
# 0    2019-02-25 09:46:13 PM  40.767272          -73.993929
# 1    2019-02-25 09:44:06 PM  40.719116          -74.006667
# 2    2019-02-25 09:45:48 PM  40.711174          -74.000165
# 3    2019-02-25 09:42:56 PM  40.683826          -73.976323
# 4    2019-02-25 09:43:57 PM  40.696089          -73.978034
# 5    2019-02-25 09:42:46 PM  40.686768          -73.959282
# 6    2019-02-25 09:42:36 PM  40.731724          -74.006744
# 7    2019-02-25 09:42:57 PM  40.727103          -74.002971
# 8    2019-02-25 09:42:50 PM  40.692395          -73.993379
# 9    2019-02-25 09:46:20 PM  40.698399          -73.980689
# 10   2019-02-25 09:44:27 PM  40.716250          -74.009106
# 11   2019-02-25 09:42:47 PM  40.720874          -73.980858
# 12   2019-02-25 09:46:12 PM  40.722104          -73.997249
# 13   2019-02-25 09:43:47 PM  40.690893          -73.996123
# 14   2019-02-25 09:43:39 PM  40.729170          -73.998102
# 15   2019-02-25 09:46:08 PM  40.753231          -73.970325
# 16   2019-02-25 09:43:56 PM  40.748901          -73.976049
# 17   2019-02-25 09:42:47 PM  40.739713          -73.994564
# 18   2019-02-25 09:44:05 PM  40.760683          -73.984527
# 19   2019-02-25 09:45:20 PM  40.738177          -73.977387
# 20   2019-02-25 09:43:52 PM  40.709056          -74.010434
# 21   2019-02-25 09:43:28 PM  40.743349          -74.006818
# 22   2019-02-25 09:44:58 PM  40.700379          -73.995481
# 23   2019-02-25 09:44:44 PM  40.702772          -73.993836
# 24   2019-02-25 09:44:02 PM  40.737815          -73.999947
# 25   2019-02-25 09:45:36 PM  40.711464          -74.005524
# 26   2019-02-25 09:43:27 PM  40.754601          -73.971879
# 27   2019-02-25 09:46:20 PM  40.727434          -73.993790
# 28   2019-02-25 09:45:03 PM  40.728419          -73.987140
# 29   2019-02-25 09:44:21 PM  40.730473          -73.986724
# ..                      ...        ...      ...        ...        ...
# 786  2019-02-25 09:45:48 PM  40.799041          -73.966495
# 787  2019-02-25 09:44:00 PM  40.713342          -74.009355
# 788  2019-02-25 09:43:37 PM  40.764089          -73.910651
# 789  2019-02-25 09:46:06 PM  40.699997          -73.974401
# 790  2019-02-25 09:44:13 PM  40.722482          -73.959219
# 791  2019-02-25 09:43:52 PM  40.711130          -74.078900
# 792  2019-02-25 09:43:17 PM  40.775160          -73.989187
# 793  2019-02-25 09:44:30 PM  40.763605          -73.989180
# 794  2019-02-25 09:45:04 PM  40.708318          -74.005041
# 795  2019-02-25 09:46:07 PM  40.743752          -73.941765
# 796  2019-02-25 09:44:13 PM  40.741459          -73.983293
# 797  2019-02-25 09:46:13 PM  40.735445          -73.994310
# 798  2019-02-25 09:45:09 PM  40.738046          -73.996430
# 799  2019-02-25 09:44:43 PM  40.729667          -73.980680
# 800  2019-02-25 09:43:59 PM  40.754692          -73.997402
# 801  2019-02-25 09:46:11 PM  40.706842          -73.954435
# 802  2019-02-25 09:44:36 PM  40.718170          -73.955201
# 803  2019-02-25 09:42:31 PM  40.753599          -73.937956
# 804  2019-02-25 09:43:05 PM  40.727464          -73.979504
# 805  2019-02-25 09:45:34 PM  40.684617          -73.987213
# 806  2019-02-25 09:44:04 PM  40.767549          -73.920933
# 807  2019-02-25 09:44:03 PM  40.695317          -73.990157
# 808  2019-02-25 09:42:22 PM  40.766741          -73.979069
# 809  2019-02-25 09:45:33 PM  40.768762          -73.958408
# 810  2019-02-25 09:44:58 PM  40.743366          -73.959607
# 811  2019-02-25 09:45:06 PM  40.717662          -73.948800
# 812  2019-02-25 09:45:36 PM  40.695357          -73.993440
# 813  2019-02-25 09:42:49 PM  40.730563          -73.973984
# 814  2019-02-25 09:45:02 PM  40.720747          -73.986274
# 815  2019-02-25 09:43:30 PM  40.756513          -73.929575
#
#                            stAddress1 stAddress2  \
# 0                    W 52 St & 11 Ave
# 1            Franklin St & W Broadway
# 2              St James Pl & Pearl St
# 3       Atlantic Ave & Fort Greene Pl
# 4            Park Ave & St Edwards St
# 5         Lexington Ave & Classon Ave
# 6               Barrow St & Hudson St
# 7            MacDougal St & Prince St
# 8           Clinton St & Joralemon St
# 9                 Nassau St & Navy St
# 10               Hudson St & Reade St
# 11                  E 2 St & Avenue C
# 12           Cleveland Pl & Spring St
# 13            Henry St & Atlantic Ave
# 14              LaGuardia Pl & W 3 St
# 15                    E 47 St & 2 Ave
# 16                    E 39 St & 3 Ave
# 17                    W 18 St & 6 Ave
# 18                 Broadway & W 49 St
# 19                    E 25 St & 1 Ave
# 20              Liberty St & Broadway
# 21            W 16 St & The High Line
# 22    Columbia Heights & Cranberry St
# 23                      Old Fulton St
# 24                    W 13 St & 7 Ave
# 25              Spruce St & Nassau St
# 26                    E 48 St & 3 Ave
# 27                     Great Jones St
# 28                St Marks Pl & 2 Ave
# 29                    E 11 St & 2 Ave
# ..                                ...        ...
# 786          W 104 St & Amsterdam Ave
# 787               Park Pl & Church St
# 788                    28 Ave & 44 St
# 789                  5 St & Market St
# 790                N 11 St & Kent Ave
# 791                    Jackson Square
# 792  W 64 St & Thelonious Monk Circle
# 793                   W 50 St & 9 Ave
# 794              Cliff St & Fulton St
# 795             47 Ave & Skillman Ave
# 796           Lexington Ave & E 26 St
# 797                   W 13 St & 5 Ave
# 798                   W 15 St & 6 Ave
# 799                E 13 St & Avenue A
# 800                W 35 St & Dyer Ave
# 801           Division Av & Hooper St
# 802               Driggs Ave & N 9 St
# 803              40 Ave & Crescent St
# 804                E 11 St & Avenue B
# 805              Wyckoff St & Bond St
# 806               31 St & Newtown Ave
# 807       Cadman Plaza E & Johnson St
# 808        7 Ave & Central Park South
# 809                   2 Ave & E 72 St
# 810              Center Blvd & 51 Ave
# 811             Frost St & Meeker Ave
# 812         Pierrepont St & Monroe Pl
# 813                Avenue C & E 18 St
# 814           Stanton St & Norfolk St
# 815                    36 Ave & 31 St
#
#                           stationName  statusKey statusValue  testStation  \
# 0                    W 52 St & 11 Ave          1  In Service        False
# 1            Franklin St & W Broadway          1  In Service        False
# 2              St James Pl & Pearl St          1  In Service        False
# 3       Atlantic Ave & Fort Greene Pl          1  In Service        False
# 4            Park Ave & St Edwards St          1  In Service        False
# 5         Lexington Ave & Classon Ave          1  In Service        False
# 6               Barrow St & Hudson St          1  In Service        False
# 7            MacDougal St & Prince St          1  In Service        False
# 8           Clinton St & Joralemon St          1  In Service        False
# 9                 Nassau St & Navy St          1  In Service        False
# 10               Hudson St & Reade St          1  In Service        False
# 11                  E 2 St & Avenue C          1  In Service        False
# 12           Cleveland Pl & Spring St          1  In Service        False
# 13            Henry St & Atlantic Ave          1  In Service        False
# 14              LaGuardia Pl & W 3 St          1  In Service        False
# 15                    E 47 St & 2 Ave          1  In Service        False
# 16                    E 39 St & 3 Ave          1  In Service        False
# 17                    W 18 St & 6 Ave          1  In Service        False
# 18                 Broadway & W 49 St          1  In Service        False
# 19                    E 25 St & 1 Ave          1  In Service        False
# 20              Liberty St & Broadway          1  In Service        False
# 21            W 16 St & The High Line          1  In Service        False
# 22    Columbia Heights & Cranberry St          1  In Service        False
# 23                      Old Fulton St          1  In Service        False
# 24                    W 13 St & 7 Ave          1  In Service        False
# 25              Spruce St & Nassau St          1  In Service        False
# 26                    E 48 St & 3 Ave          1  In Service        False
# 27                     Great Jones St          1  In Service        False
# 28                St Marks Pl & 2 Ave          1  In Service        False
# 29                    E 11 St & 2 Ave          1  In Service        False
# ..                                ...        ...         ...          ...
# 786          W 104 St & Amsterdam Ave          1  In Service        False
# 787               Park Pl & Church St          1  In Service        False
# 788                    28 Ave & 44 St          1  In Service        False
# 789                  5 St & Market St          1  In Service        False
# 790                N 11 St & Kent Ave          1  In Service        False
# 791                    Jackson Square          1  In Service        False
# 792  W 64 St & Thelonious Monk Circle          1  In Service        False
# 793                   W 50 St & 9 Ave          1  In Service        False
# 794              Cliff St & Fulton St          1  In Service        False
# 795             47 Ave & Skillman Ave          1  In Service        False
# 796           Lexington Ave & E 26 St          1  In Service        False
# 797                   W 13 St & 5 Ave          1  In Service        False
# 798                   W 15 St & 6 Ave          1  In Service        False
# 799                E 13 St & Avenue A          1  In Service        False
# 800                W 35 St & Dyer Ave          1  In Service        False
# 801           Division Av & Hooper St          1  In Service        False
# 802               Driggs Ave & N 9 St          1  In Service        False
# 803              40 Ave & Crescent St          1  In Service        False
# 804                E 11 St & Avenue B          1  In Service        False
# 805              Wyckoff St & Bond St          1  In Service        False
# 806               31 St & Newtown Ave          1  In Service        False
# 807       Cadman Plaza E & Johnson St          1  In Service        False
# 808        7 Ave & Central Park South          1  In Service        False
# 809                   2 Ave & E 72 St          1  In Service        False
# 810              Center Blvd & 51 Ave          1  In Service        False
# 811             Frost St & Meeker Ave          1  In Service        False
# 812         Pierrepont St & Monroe Pl          1  In Service        False
# 813                Avenue C & E 18 St          1  In Service        False
# 814           Stanton St & Norfolk St          1  In Service        False
# 815                    36 Ave & 31 St          1  In Service        False
#
#      totalDocks
# 0            55
# 1            33
# 2            27
# 3            62
# 4            19
# 5            19
# 6            31
# 7            30
# 8            24
# 9            19
# 10           39
# 11           54
# 12           33
# 13           23
# 14           35
# 15           47
# 16           45
# 17           47
# 18           51
# 19           30
# 20           45
# 21           28
# 22           23
# 23           39
# 24           33
# 25           31
# 26           55
# 27           23
# 28           47
# 29           39
# ..          ...
# 786          47
# 787          36
# 788          19
# 789          15
# 790          27
# 791          18
# 792          43
# 793          30
# 794          37
# 795          19
# 796          55
# 797          29
# 798          51
# 799          47
# 800          41
# 801          61
# 802          31
# 803          23
# 804          46
# 805          23
# 806          35
# 807          30
# 808          39
# 809          41
# 810          20
# 811          38
# 812          24
# 813          46
# 814          35
# 815          27
#
# [816 rows x 18 columns]

# %%
# there is one row for each bike station.  How many stations are there? 
len(df)
# Out:
# 816

# %%
# in the file above, there are lon-lats, but no geometry field
# we need to set that up

s = gp.GeoSeries([Point(x, y) for x, y in zip(df['longitude'], df['latitude'])])
df['geometry'] = s
df.crs = {'init': 'epsg:4326', 'no_defs': True}
df.geometry.total_bounds
df.crs
# Out:
# {'init': 'epsg:4326', 'no_defs': True}

# %%
# make sure they are on the same CRS.  
# checking the bounds is a nice way of seeing this
df.to_crs(boros.crs, inplace=True)
df.geometry.total_bounds
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-7092eae126a3> in <module>
#       1 # make sure they are on the same CRS.
#       2 # checking the bounds is a nice way of seeing this
# ----> 3 df.to_crs(boros.crs, inplace=True)
#       4 df.geometry.total_bounds
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in to_crs(self, crs, epsg, inplace)
#     441         else:
#     442             df = self.copy()
# --> 443         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#     444         df.geometry = geom
#     445         df.crs = geom.crs
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geoseries.py in to_crs(self, crs, epsg)
#     302             except TypeError:
#     303                 raise TypeError('Must set either crs or epsg for output.')
# --> 304         proj_in = pyproj.Proj(self.crs, preserve_units=True)
#     305         proj_out = pyproj.Proj(crs, preserve_units=True)
#     306         project = partial(pyproj.transform, proj_in, proj_out)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyproj\__init__.py in __new__(self, projparams, preserve_units, **kwargs)
#     360         # on case-insensitive filesystems).
#     361         projstring = projstring.replace('EPSG','epsg')
# --> 362         return _proj.Proj.__new__(self, projstring)
#     363
#     364     def __call__(self, *args, **kw):
#
# _proj.pyx in _proj.Proj.__cinit__()
#
# RuntimeError: b'no arguments in initialization list'

# %%
# the geometry objects can do lots of cool stuff.  For example: 

manhattan = boros.geometry[3]
in_mn = df.geometry.within(manhattan)
print(sum(in_mn), 'stations in Manhattan')
# Out:
# 0 stations in Manhattan

# %% [markdown]
# # Your turn
#
# You can read about the range of operations available in geopandas here:
#
# http://geopandas.org/index.html
#
# Your assignment is to:
#
# 1. Calculate how many stations are in each borough
# 2. Calculate how many bikes are currently available in each borough
# 3. Read about and try at least two new spatial or geometric operations (beyond what I've covered here).

# %% [markdown]
# ### 1. Calculate how many stations are in each borough

# %%
# join the citibike data with boros using the within operation
citibikes_boros = gp.sjoin(df, boros, how="left", op='within')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\tools\sjoin.py:44: UserWarning: CRS of frames being joined does not match!
#   warn('CRS of frames being joined does not match!')

# %%
#Note, 50 stations are not within any boro
sum(citibikes_boros.BoroName.isna())
# Out:
# 816

# %%
c = citibikes_boros.BoroName.value_counts().to_frame(name='stations')
# Add boros with 0 stations
pd.merge(boros[['BoroName']],c, how='left', right_index=True, left_on= 'BoroName').fillna(0)
# Out:
#         BoroName  stations
# 0  Staten Island       0.0
# 1       Brooklyn       0.0
# 2         Queens       0.0
# 3      Manhattan       0.0
# 4          Bronx       0.0

# %% [markdown]
# ### 2. Calculate how many bikes are currently available in each borough

# %%
# get sum of bikes
bikes = citibikes_boros.groupby('BoroName')['availableBikes'].sum()
bikes
# Out:
# Series([], Name: availableBikes, dtype: int64)

# %%
# Add boros with 0 bikes
bikes = bikes.to_frame(name='bikes')
pd.merge(boros[['BoroName']],bikes, right_index=True, left_on= 'BoroName', how='left').fillna(0)
# Out:
#         BoroName  bikes
# 0  Staten Island    0.0
# 1       Brooklyn    0.0
# 2         Queens    0.0
# 3      Manhattan    0.0
# 4          Bronx    0.0

# %% [markdown]
# ### 3. Read about and try at least two new spatial or geometric operations (beyond what I've covered here).
#
# 1. sjoin() - Used in exercise one
# 2. dissolve(): It dissolves all the geometries within a given group together into a single geometric feature
# 3. touches(): It checks if two objects has at least one point in common and the interior of one does not intersect with any part of the other.

# %%
try_touches = boros.BoroName.to_frame()
for index, row in boros.iterrows():
    try_touches[row.BoroName] = boros.geometry.touches(row.geometry)
    
try_touches
# Out:
#         BoroName  Staten Island  Brooklyn  Queens  Manhattan  Bronx
# 0  Staten Island          False     False   False      False  False
# 1       Brooklyn          False     False    True       True  False
# 2         Queens          False      True   False       True   True
# 3      Manhattan          False      True    True      False   True
# 4          Bronx          False     False    True       True  False
